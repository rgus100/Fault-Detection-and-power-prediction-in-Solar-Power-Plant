# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %%
p1gd = pd.read_csv('/content/drive/MyDrive/BTP_data/Plant_1_Generation_Data.csv')
p2gd = pd.read_csv('/content/drive/MyDrive/BTP_data/Plant_2_Generation_Data.csv')
p1wd = pd.read_csv('/content/drive/MyDrive/BTP_data/Plant_1_Weather_Sensor_Data.csv')
p2wd = pd.read_csv('/content/drive/MyDrive/BTP_data/Plant_2_Weather_Sensor_Data.csv')

# %%
p1gd.head()
# Out:
#           DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD
# 0          0.0    6259559.0
# 1          0.0    6183645.0
# 2          0.0    6987759.0
# 3          0.0    7602960.0
# 4          0.0    7158964.0

# %%
p2gd.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  2020-05-15 00:00:00   4136001  4UPUqMRk7TRMgml       0.0       0.0
# 1  2020-05-15 00:00:00   4136001  81aHJ1q11NBPMrL       0.0       0.0
# 2  2020-05-15 00:00:00   4136001  9kRcWv60rDACzjR       0.0       0.0
# 3  2020-05-15 00:00:00   4136001  Et9kgGMDl729KT4       0.0       0.0
# 4  2020-05-15 00:00:00   4136001  IQ2d7wF4YD8zU1Q       0.0       0.0
#
#    DAILY_YIELD   TOTAL_YIELD
# 0  9425.000000  2.429011e+06
# 1     0.000000  1.215279e+09
# 2  3075.333333  2.247720e+09
# 3   269.933333  1.704250e+06
# 4  3177.000000  1.994153e+07

# %%
p1wd.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1  2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2  2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3  2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4  2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION
# 0           22.857507          0.0
# 1           22.761668          0.0
# 2           22.592306          0.0
# 3           22.360852          0.0
# 4           22.165423          0.0

# %%
p2wd.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00   4136001  iq8k7ZNt4Mwm3w0            27.004764
# 1  2020-05-15 00:15:00   4136001  iq8k7ZNt4Mwm3w0            26.880811
# 2  2020-05-15 00:30:00   4136001  iq8k7ZNt4Mwm3w0            26.682055
# 3  2020-05-15 00:45:00   4136001  iq8k7ZNt4Mwm3w0            26.500589
# 4  2020-05-15 01:00:00   4136001  iq8k7ZNt4Mwm3w0            26.596148
#
#    MODULE_TEMPERATURE  IRRADIATION
# 0           25.060789          0.0
# 1           24.421869          0.0
# 2           24.427290          0.0
# 3           24.420678          0.0
# 4           25.088210          0.0

# %%
p2gd.describe()
# Out:
#         PLANT_ID      DC_POWER      AC_POWER   DAILY_YIELD   TOTAL_YIELD
# count    67698.0  67698.000000  67698.000000  67698.000000  6.769800e+04
# mean   4136001.0    246.701961    241.277825   3294.890295  6.589448e+08
# std          0.0    370.569597    362.112118   2919.448386  7.296678e+08
# min    4136001.0      0.000000      0.000000      0.000000  0.000000e+00
# 25%    4136001.0      0.000000      0.000000    272.750000  1.996494e+07
# 50%    4136001.0      0.000000      0.000000   2911.000000  2.826276e+08
# 75%    4136001.0    446.591667    438.215000   5534.000000  1.348495e+09
# max    4136001.0   1420.933333   1385.420000   9873.000000  2.247916e+09

# %%
p1gd.shape
# Out:
# (68778, 7)

# %%
p1wd.shape
# Out:
# (3182, 6)

# %%
p1gd['AC_POWER']=p1gd['AC_POWER']*10
p1gd.describe()
# Out:
#         PLANT_ID      DC_POWER      AC_POWER   DAILY_YIELD   TOTAL_YIELD
# count    68778.0  68778.000000  68778.000000  68778.000000  6.877800e+04
# mean   4135001.0   3147.426211   3078.027523   3295.968737  6.978712e+06
# std          0.0   4036.457169   3943.964387   3145.178309  4.162720e+05
# min    4135001.0      0.000000      0.000000      0.000000  6.183645e+06
# 25%    4135001.0      0.000000      0.000000      0.000000  6.512003e+06
# 50%    4135001.0    429.000000    414.937500   2658.714286  7.146685e+06
# 75%    4135001.0   6366.964286   6236.187500   6274.000000  7.268706e+06
# max    4135001.0  14471.125000  14109.500000   9163.000000  7.846821e+06

# %%
p1wd.describe()
# Out:
#         PLANT_ID  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# count     3182.0          3182.000000         3182.000000  3182.000000
# mean   4135001.0            25.531606           31.091015     0.228313
# std          0.0             3.354856           12.261222     0.300836
# min    4135001.0            20.398505           18.140415     0.000000
# 25%    4135001.0            22.705182           21.090553     0.000000
# 50%    4135001.0            24.613814           24.618060     0.024653
# 75%    4135001.0            27.920532           41.307840     0.449588
# max    4135001.0            35.252486           65.545714     1.221652

# %% [markdown]
# Lets' See How many Inverters are there in the plants and how many values have been recorded by each of them

# %%
p1gd.groupby('SOURCE_KEY')['DATE_TIME'].count()
# Out:
# SOURCE_KEY
# 1BY6WEcLGh8j5v7    3154
# 1IF53ai7Xc0U56Y    3119
# 3PZuoBAID5Wc2HD    3118
# 7JYdWkrLSPkdwr4    3133
# McdE0feGgRqW7Ca    3124
# VHMLBKoKgIrUVDU    3133
# WRmjgnKYAwPKWDb    3118
# YxYtjZvoooNbGkE    3104
# ZnxXDlPa8U1GXgE    3130
# ZoEaEvLYb1n2sOq    3123
# adLQvlD726eNBSB    3119
# bvBOhCH3iADSZry    3155
# iCRJl6heRkivqQ3    3125
# ih0vzX44oOqAx2f    3130
# pkci93gMrogZuBj    3125
# rGa61gmuvPhdLxV    3124
# sjndEbLyjtCKgGv    3124
# uHbuxQJl8lW7ozc    3125
# wCURE6d3bPkepu2    3126
# z9Y9gH1T5YWrNuG    3126
# zBIq5rxdHJRwDNY    3119
# zVJPv84UY57bAof    3124
# Name: DATE_TIME, dtype: int64

# %%
p1gd['DATE_TIME'] = pd.to_datetime(p1gd['DATE_TIME'],format = '%d-%m-%Y %H:%M')
p1wd['DATE_TIME'] = pd.to_datetime(p1wd['DATE_TIME'],format = '%Y-%m-%d %H:%M:%S')
p2gd['DATE_TIME'] = pd.to_datetime(p2gd['DATE_TIME'],format = '%Y-%m-%d %H:%M')
p2wd['DATE_TIME'] = pd.to_datetime(p2wd['DATE_TIME'],format = '%Y-%m-%d %H:%M')

# %%
p2gd['DATE'] = p2gd['DATE_TIME'].apply(lambda x:x.date())
p2gd['TIME'] = p2gd['DATE_TIME'].apply(lambda x:x.time())
p2wd['DATE'] = p2wd['DATE_TIME'].apply(lambda x:x.date())
p2wd['TIME'] = p2wd['DATE_TIME'].apply(lambda x:x.time())

# %%
p1gd['DATE'] = p1gd['DATE_TIME'].apply(lambda x:x.date())
p1gd['TIME'] = p1gd['DATE_TIME'].apply(lambda x:x.time())
p1wd['DATE'] = p1wd['DATE_TIME'].apply(lambda x:x.date())
p1wd['TIME'] = p1wd['DATE_TIME'].apply(lambda x:x.time())

# %%
p2gd=p2gd.set_index("DATE")

# %%
p2wd=p2wd.set_index("DATE")

# %%
p1wd=p1wd.set_index("DATE")
p1gd=p1gd.set_index("DATE")

# %% [markdown]
# Plant-1

# %%
print(p1wd.shape)
for col in ['AMBIENT_TEMPERATURE','MODULE_TEMPERATURE','IRRADIATION']:
  p1wd=p1wd[p1wd[col]!=-9999]
print(p1wd.shape)

#There is no missing value in Plant-1 weather data.
# Out:
# (3182, 7)
# (3182, 7)

# %%
print(p2wd.shape)
for col in ['AMBIENT_TEMPERATURE','MODULE_TEMPERATURE','IRRADIATION']:
  p2wd=p2wd[p2wd[col]!=-9999]
print(p2wd.shape)

#There is no missing value in Plant-2 weather data.
# Out:
# (3259, 7)
# (3259, 7)

# %%
print(p1gd.shape)
for col in ['DC_POWER','AC_POWER','DAILY_YIELD','TOTAL_YIELD']:
  p1gd=p1gd[p1gd[col]!=-9999]
print(p1gd.shape)

#There is no missing value in Plant-1 generation data.
# Out:
# (68778, 8)
# (68778, 8)

# %%
print(p2gd.shape)
for col in ['DC_POWER','AC_POWER','DAILY_YIELD','TOTAL_YIELD']:
  p2gd=p2gd[p2gd[col]!=-9999]
print(p2gd.shape)
# Out:
# (67698, 8)
# (67698, 8)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit(p1gd['SOURCE_KEY'])
p1gd['SOURCE']=le.transform(p1gd['SOURCE_KEY'])

# %%
p1gd['SOURCE']
# Out:
# DATE
# 2020-05-15     0
# 2020-05-15     1
# 2020-05-15     2
# 2020-05-15     3
# 2020-05-15     4
#               ..
# 2020-06-17    17
# 2020-06-17    18
# 2020-06-17    19
# 2020-06-17    20
# 2020-06-17    21
# Name: SOURCE, Length: 68778, dtype: int64

# %% [markdown]
# Generation Data

# %%
(p2gd['SOURCE_KEY'].unique())
# Out:
# array(['4UPUqMRk7TRMgml', '81aHJ1q11NBPMrL', '9kRcWv60rDACzjR',
#        'Et9kgGMDl729KT4', 'IQ2d7wF4YD8zU1Q', 'LYwnQax7tkwH5Cb',
#        'LlT2YUhhzqhg5Sw', 'Mx2yZCDsyf6DPfv', 'NgDl19wMapZy17u',
#        'PeE6FRyGXUgsRhN', 'Qf4GUc1pJu5T6c6', 'Quc1TzYxW2pYoWX',
#        'V94E5Ben1TlhnDV', 'WcxssY2VbP4hApt', 'mqwcsP2rE7J0TFp',
#        'oZ35aAeoifZaQzV', 'oZZkBaNadn6DNKz', 'q49J1IKaHRwDQnt',
#        'rrq4fwE8jgrTyWY', 'vOuJvMaM2sgwLmb', 'xMbIugepa2P7lBB',
#        'xoJJ8DcxJEcupym'], dtype=object)

# %% [markdown]
# DC power generation from Solar Panels to particular Inverters

# %%
p2_dc_pwr = p2gd.copy()
p2_dc_pwr = p2_dc_pwr.groupby(['TIME','SOURCE_KEY'])['DC_POWER'].mean().unstack()

fig,ax=plt.subplots(ncols=3,nrows=1,dpi=200,figsize=(20,5))
ax[0].set_title('DC Power Generation to 1st 7 Inverters for plant 2')
ax[1].set_title('DC Power Generation to next 8 Inverters for plant 2')
ax[2].set_title('DC Power Generation to last 7 Inverters for plant 2')
ax[0].set_ylabel('DC POWER in kW')


p2_dc_pwr.iloc[:,0:7].plot(ax=ax[0],linewidth = 5)
p2_dc_pwr.iloc[:,7:15].plot(ax=ax[1],linewidth = 5)
p2_dc_pwr.iloc[:,15:22].plot(ax=ax[2],linewidth = 5)

# %% [markdown]
# From the DC Power Generation plot it is clear that substantially low DC Power is coming to Inverters "Et9kgGMDl729KT4", "LYwnQax7tkwH5Cb", "Quc1TzYxW2pYoWX" and "rrq4fwE8jgrTyWY"
#
# Hence,Solar Modules connected to these Inverters are recommended to be cleaned, observed for any shadow coming from nearby objects. Also, these Solar Modules and/or Strings are to be checked for any fault.

# %%
startdate = pd.to_datetime("2020-05-15").date()
enddate = pd.to_datetime("2020-05-25").date()

p2_dc_pwr = p2gd.copy()
p2_dc_pwr = p2_dc_pwr.loc[startdate:enddate,:].groupby(['TIME','SOURCE_KEY'])['DC_POWER'].mean().unstack()

fig,ax=plt.subplots(ncols=3,nrows=1,dpi=200,figsize=(20,5))
ax[0].set_title('DC Power Generation:-1st 7 Inverters for plant 2 from 15 to 25 May')
ax[1].set_title('DC Power Generation:-next 8 Inverters for plant 2 from 15 to 25 May')
ax[2].set_title('DC Power Generation:-last 7 Inverters for plant 2 from 15 to 25 May')
ax[0].set_ylabel('DC POWER in kW')


p2_dc_pwr.iloc[:,0:7].plot(ax=ax[0],linewidth = 5)
p2_dc_pwr.iloc[:,7:15].plot(ax=ax[1],linewidth = 5)
p2_dc_pwr.iloc[:,15:22].plot(ax=ax[2],linewidth = 5)

# %% [markdown]
# By looking at above plots we can say that for 1st to 7th inverter the power output is low so it may be due to some weather condition. But for inverter Quc1TzYxW2pYoWX itthere may be some technical problem.
# Let's Analyze the second power plant to get more insights

# %% [markdown]
# ## Fault Prediction of 2nd power plant

# %% [markdown]
# Plotting DC Power generation and weather conditions for plant 2 on daily basis

# %%
solar_dc = p2gd.pivot_table(values='DC_POWER', index='TIME', columns='DATE')
solar_ac = p2gd.pivot_table(values='AC_POWER', index='TIME', columns='DATE')
# print(solar_dc.head())
def Daywise_plot(data= None,data1=None, row = None, col = None, title='AC & DC Power'):
    cols = data.columns # take all column
    cols1=data1.columns
    gp = plt.figure(figsize=(20,40)) 
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(cols)+1):
        ax = gp.add_subplot(row,col, i)
        data[cols[i-1]].plot(ax=ax, color='red')
        data1[cols1[i-1]].plot(ax=ax,linestyle='dotted', color='blue')
        ax.set_title('{} {}'.format(title, cols[i-1]),color='blue')
        ax.set_ylabel('Kw')
        ax.legend(['DC POWER','AC POWER'])
    plt.show()
        
Daywise_plot(data=solar_dc,data1=solar_ac, row=12, col=3)

# %% [markdown]
# Note: Reason for very high Fluctuation & Reduction in DC_POWER generation is due to fault in the system or may be fluctuation in weather or due to clouds etc. which need to be analyse further
#
# ---

# %%
daily_dc = p2gd.groupby('DATE')['DC_POWER'].agg('sum')
daily_ac = p2gd.groupby('DATE')['AC_POWER'].agg('sum')
daily_ac = daily_ac.sort_values(ascending=False)
daily_dc = daily_dc.sort_values(ascending=False)
df=pd.DataFrame()
df['AC']=daily_ac.values
df['DATE']=daily_ac.index
df['DC']=daily_dc.values
df.plot(x='DATE',y=['AC','DC'],kind='bar',figsize=(17,5), legend=True,color=['blue','orange'])
plt.title('Daily AC & DC Power')
plt.ylabel('Kw')
plt.legend(['AC POWER','DC POWER'])
plt.show()

# %% [markdown]
# Form the per day DC_POWER generation graph we can find the average power generation per day.
#
# Highest average DC_POWER Generation is on: 2020-05-15
#
# Lowest average DC_POWER Generation is on : 2020-06-11

# %% [markdown]
# Multiple Plotting of MODULE_TEMPERATURE & AMBIENT_TEMPERATURE generation on per day basis

# %%
solar_irradiation = p2wd.pivot_table(values='IRRADIATION', index='TIME', columns='DATE')
mod_temp = p2wd.pivot_table(values='MODULE_TEMPERATURE', index='TIME', columns='DATE')
amb_temp = p2wd.pivot_table(values='AMBIENT_TEMPERATURE', index='TIME', columns='DATE')

def Daywise_plot_rad(amb=None,mod=None, row = None, col = None, title='Weather Data'):
    col1=amb.columns
    col2=mod.columns
    gp = plt.figure(figsize=(20,40)) 
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(col1)+1):
        ax = gp.add_subplot(row,col, i)
        amb[col1[i-1]].plot(ax=ax, color='green')
        mod[col2[i-1]].plot(ax=ax, color='red')
        ax.legend(['AMBIENT TEMP','MODULE TEMP'])
        ax.set_title('{} {}'.format(title, col1[i-1]),color='blue')
def Daywise_plot(data= None, row = None, col = None, title='Irradiation Data'):
    cols = data.columns # take all column
    gp = plt.figure(figsize=(20,40)) 
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(cols)+1):
        ax = gp.add_subplot(row,col, i)
        data[cols[i-1]].plot(ax=ax, color='blue')
        ax.legend(['IRRADIATION'])
        ax.set_title('{} {}'.format(title, cols[i-1]),color='blue')

        
Daywise_plot_rad(amb=amb_temp,mod=mod_temp, row=12, col=3)
Daywise_plot(data=solar_irradiation, row=12, col=3)

# %% [markdown]
# IRRADIATION graph pattern is looking very similar to the corresponding DC_POWER generation on per day basis.
# In solar power plant DC_POWER or Output power is mostly depends on IRRADIATION .Or it is not wrong to say that it’s directly proportional.

# %%
daily_irradiation = p2wd.groupby('DATE')['IRRADIATION'].agg('mean')

daily_irradiation.sort_values(ascending=False).plot.bar(figsize=(17,5), legend=True,color='blue')
plt.title('IRRADIATION')
plt.show()

# %%
daily_ambient_temp = p2wd.groupby('DATE')['AMBIENT_TEMPERATURE'].agg('mean')

daily_ambient_temp.sort_values(ascending=False).plot.bar(figsize=(17,5), legend=True,color='darkgreen')
plt.title('AMBIENT_TEMPERATURE')
plt.show()

# %%
p1_dc_pwr = p1gd.copy()
p1_dc_pwr = p1_dc_pwr.groupby(['TIME','SOURCE_KEY'])['AC_POWER'].mean().unstack()

fig,ax=plt.subplots(ncols=3,nrows=1,dpi=200,figsize=(20,5))
ax[0].set_title('DC Power Generation to 1st 7 Inverters for plant 1')
ax[1].set_title('DC Power Generation to next 8 Inverters for plant 1')
ax[2].set_title('DC Power Generation to last 7 Inverters for plant 1')
ax[0].set_ylabel('DC POWER in kW')


p1_dc_pwr.iloc[:,0:7].plot(ax=ax[0],linewidth = 5)
p1_dc_pwr.iloc[:,7:15].plot(ax=ax[1],linewidth = 5)
p1_dc_pwr.iloc[:,15:22].plot(ax=ax[2],linewidth = 5)

# %% [markdown]
# DC Power Generation from Plant 1

# %% [markdown]
# Plant 1 seems fine

# %% [markdown]
# Predicting AC POWER using Regression:

# %% [markdown]
# Data for Regression- AC Power generation of the plant will certainly depend on Irradiation, Ambient Temperature and Module Temperature. Howevere, to predict the AC Power we will have the Weather Forecast data (i.e. Irradiation and Ambient Temperature) only.

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as mse
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# -----------------------------------------------------------------------------------

# %%
df_gen1 = pd.read_csv('/content/drive/MyDrive/BTP_data/Plant_1_Generation_Data.csv')
df_gen2 = pd.read_csv('/content/drive/MyDrive/BTP_data/Plant_2_Generation_Data.csv')
df_weather1 = pd.read_csv('/content/drive/MyDrive/BTP_data/Plant_1_Weather_Sensor_Data.csv')
df_weather2 = pd.read_csv('/content/drive/MyDrive/BTP_data/Plant_2_Weather_Sensor_Data.csv')

# %%
print(df_gen2.SOURCE_KEY.unique())
print(df_gen1.SOURCE_KEY.unique())
# Out:
# ['4UPUqMRk7TRMgml' '81aHJ1q11NBPMrL' '9kRcWv60rDACzjR' 'Et9kgGMDl729KT4'
#  'IQ2d7wF4YD8zU1Q' 'LYwnQax7tkwH5Cb' 'LlT2YUhhzqhg5Sw' 'Mx2yZCDsyf6DPfv'
#  'NgDl19wMapZy17u' 'PeE6FRyGXUgsRhN' 'Qf4GUc1pJu5T6c6' 'Quc1TzYxW2pYoWX'
#  'V94E5Ben1TlhnDV' 'WcxssY2VbP4hApt' 'mqwcsP2rE7J0TFp' 'oZ35aAeoifZaQzV'
#  'oZZkBaNadn6DNKz' 'q49J1IKaHRwDQnt' 'rrq4fwE8jgrTyWY' 'vOuJvMaM2sgwLmb'
#  'xMbIugepa2P7lBB' 'xoJJ8DcxJEcupym']
# ['1BY6WEcLGh8j5v7' '1IF53ai7Xc0U56Y' '3PZuoBAID5Wc2HD' '7JYdWkrLSPkdwr4'
#  'McdE0feGgRqW7Ca' 'VHMLBKoKgIrUVDU' 'WRmjgnKYAwPKWDb' 'ZnxXDlPa8U1GXgE'
#  'ZoEaEvLYb1n2sOq' 'adLQvlD726eNBSB' 'bvBOhCH3iADSZry' 'iCRJl6heRkivqQ3'
#  'ih0vzX44oOqAx2f' 'pkci93gMrogZuBj' 'rGa61gmuvPhdLxV' 'sjndEbLyjtCKgGv'
#  'uHbuxQJl8lW7ozc' 'wCURE6d3bPkepu2' 'z9Y9gH1T5YWrNuG' 'zBIq5rxdHJRwDNY'
#  'zVJPv84UY57bAof' 'YxYtjZvoooNbGkE']

# %% [markdown]
# Right now, we have rows based on each inverter i.e. each timestamp is being repeated the number of inverters for which data is present for that particular time stamp. But we want our predictions to be on the plant level day wise divided into each 15 min timestamp. Hence the desired format is day-wise (timestamp-wise) rows from 00:00 to 24:00 with columns being the sum of all inverter values(for DC Power, AC Power…) for that timestamp as shown below.
# For this, we shall first group our data inverter wise & store each group in a list. Then will merge each group with the next one using outer join on DATE_TIME column

# %%
#Dropping PLANT_ID 
df_gen1.drop('PLANT_ID', axis=1, inplace=True)
df_weather1.drop('PLANT_ID', axis = 1, inplace=True)
df_gen2.drop('PLANT_ID', axis=1, inplace=True)
df_weather2.drop('PLANT_ID', axis = 1, inplace=True)
## Mapping
Inverter_labels1 = {inverter_no:inverter_name for inverter_name,inverter_no in enumerate(df_gen1['SOURCE_KEY'].unique(),1)}
Inverter_labels2 = {inverter_no:inverter_name for inverter_name,inverter_no in enumerate(df_gen2['SOURCE_KEY'].unique(),1)}
df_gen1['Inverter_No'] = df_gen1['SOURCE_KEY'].map(Inverter_labels1) 
df_gen2['Inverter_No'] = df_gen2['SOURCE_KEY'].map(Inverter_labels2) 

## Drop Source Key after replacing with inverter numbers
df_gen1.drop('SOURCE_KEY',axis=1,inplace=True)
df_gen2.drop('SOURCE_KEY',axis=1,inplace=True)
df_weather1.drop('SOURCE_KEY',axis=1,inplace=True) 
df_weather2.drop('SOURCE_KEY',axis=1,inplace=True)

# %%
df_gen1 = df_gen1[['DATE_TIME','Inverter_No' ,'DC_POWER', 'AC_POWER']]
df_gen2 = df_gen2[['DATE_TIME','Inverter_No' ,'DC_POWER', 'AC_POWER']]

# %%
print(df_gen2[df_gen2['Inverter_No']==22][df_gen2['DC_POWER']>0.0].describe())
# Out:
#        Inverter_No     DC_POWER     AC_POWER
# count       1522.0  1522.000000  1522.000000
# mean          22.0   515.887603   504.554994
# std            0.0   375.758238   366.917818
# min           22.0     0.480000     0.466667
# 25%           22.0   169.023333   165.508333
# 50%           22.0   480.683333   471.400000
# 75%           22.0   809.893333   791.805000
# max           22.0  1406.166667  1371.013333
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
from functools import reduce
def func(dfg):
  grouped = dfg.groupby('Inverter_No')

## Making a list of each Inverter group 
  dfs = list()
  for i in dfg['Inverter_No'].unique():
      dfs.append(grouped.get_group(i))
  

 ## Merging data inverterwise using 'reduce'
 ## Applying merge function to all of the list elements of 'dfs' in the sequence passed.

  df_new = reduce(lambda left,right: pd.merge(left,right,on=['DATE_TIME'],how='outer'),dfs)

  df_new.head()
#Rename columns
  df_new.columns = ['DATE_TIME',
        'DC_POWER_1', 'AC_POWER_1',
        'Inverter_No_1', 'DC_POWER_2', 'AC_POWER_2',
        'Inverter_No_2', 'DC_POWER_3', 'AC_POWER_3',
        'Inverter_No_3', 'DC_POWER_4', 'AC_POWER_4',
        'Inverter_No_4', 'DC_POWER_5', 'AC_POWER_5',
        'Inverter_No_5', 'DC_POWER_6', 'AC_POWER_6',
        'Inverter_No_6', 'DC_POWER_7', 'AC_POWER_7',
        'Inverter_No_7', 'DC_POWER_8', 'AC_POWER_8',
        'Inverter_No_8', 'DC_POWER_9', 'AC_POWER_9',
        'Inverter_No_9', 'DC_POWER_10', 'AC_POWER_10',
        'Inverter_No_10', 'DC_POWER_11', 'AC_POWER_11',
        'Inverter_No_11', 'DC_POWER_12', 'AC_POWER_12',
        'Inverter_No_12', 'DC_POWER_13', 'AC_POWER_13',
        'Inverter_No_13', 'DC_POWER_14', 'AC_POWER_14',
        'Inverter_No_14', 'DC_POWER_15', 'AC_POWER_15',
        'Inverter_No_15', 'DC_POWER_16', 'AC_POWER_16',
        'Inverter_No_16', 'DC_POWER_17', 'AC_POWER_17',
        'Inverter_No_17', 'DC_POWER_18', 'AC_POWER_18',
        'Inverter_No_18', 'DC_POWER_19', 'AC_POWER_19',
        'Inverter_No_19', 'DC_POWER_20', 'AC_POWER_20',
        'Inverter_No_20', 'DC_POWER_21', 'AC_POWER_21',
        'Inverter_No_21', 'DC_POWER_22', 'AC_POWER_22',
        'Inverter_No_22']
  return df_new

# %%
df_gen1=func(df_gen1)
df_gen2=func(df_gen2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: FutureWarning: Passing 'suffixes' which cause duplicate columns {'AC_POWER_x', 'DC_POWER_x', 'Inverter_No_x'} in the result is deprecated and will raise a MergeError in a future version.

# %%
# dfgen1.head()
dfgn1=pd.merge(df_gen1,df_weather1,how='outer', on='DATE_TIME')
dfgn2=pd.merge(df_gen2,df_weather2,how='outer', on='DATE_TIME')

# %%
dfg1=dfgn1
dfg2=dfgn2

# %%
dfg1.isna().sum()
# Out:
# DATE_TIME                 0
# DC_POWER_1             3186
# AC_POWER_1             3186
# Inverter_No_1          3186
# DC_POWER_2             3221
#                        ...
# AC_POWER_22            3236
# Inverter_No_22         3236
# AMBIENT_TEMPERATURE    3158
# MODULE_TEMPERATURE     3158
# IRRADIATION            3158
# Length: 70, dtype: int64

# %%
dfg2=dfg2.dropna()

# %%
dfg2['DATE_TIME'] = pd.to_datetime(dfg2['DATE_TIME'],format = '%Y-%m-%d %H:%M:%S')
dfg2['DATE'] = dfg2['DATE_TIME'].apply(lambda x:x.date())
dfg2['TIME'] = dfg2['DATE_TIME'].apply(lambda x:x.time())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#Will collect all names like DC_POWER_1, DC_POWER_2 and so on 
DC_cols = [i for i in dfg1.columns if 'DC_POWER' in i]
AC_cols = [i for i in dfg1.columns if 'AC_POWER' in i]

def data_prep(df):

    # Left NaN value for generating hours(6 am to 6pm) 
       
        #1.AC & DC columns
       #2.Left NaN values in Irradiation, Ambient Temp, Module Temp, Inverter_No
    
    # Summing up Inverter wise AC and DC values to reach Plant-level generation
    df['AC_POWER'] = df.loc[: ,AC_cols].sum(axis=1)
    df['DC_POWER'] = df.loc[:,DC_cols].sum(axis=1)
    #Scaling generation to MW from kW  
    df['AC_POWER'] = df['AC_POWER']/1000.0
    df['DC_POWER'] = df['DC_POWER']/1000.0
    
    return df
dfg2=data_prep(dfg2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
scaler=StandardScaler()
scaler.fit_transform(np.array(dfg2[['AMBIENT_TEMPERATURE','MODULE_TEMPERATURE']]).reshape(-1,1))
# Out:
# array([[-0.30541439],
#        [-0.54486909],
#        [-0.32068257],
#        ...,
#        [-0.87583333],
#        [-0.77372353],
#        [-0.85587862]])

# %%
y= dfg2['AC_POWER']
X=dfg2[['IRRADIATION','AMBIENT_TEMPERATURE','MODULE_TEMPERATURE']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=5)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X)
# Out:
# (1413, 3) (1413,)
# (942, 3) (942,)
#       IRRADIATION  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE
# 0             0.0            27.004764           25.060789
# 1             0.0            26.880811           24.421869
# 2             0.0            26.682055           24.427290
# 3             0.0            26.500589           24.420678
# 4             0.0            26.596148           25.088210
# ...           ...                  ...                 ...
# 3190          0.0            23.511703           22.856201
# 3191          0.0            23.482282           22.744190
# 3192          0.0            23.354743           22.492245
# 3193          0.0            23.291048           22.373909
# 3194          0.0            23.202871           22.535908
#
# [2355 rows x 3 columns]

# %%
dfmodel=pd.DataFrame()
idx=0

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
pred_y_train = lm.predict(X_train)
y_pred = lm.predict(X_test)

# %%
err=np.sqrt((np.square(np.array(y_test)-np.array(y_pred))).sum())
dfmodel.loc[idx,'Name'] = 'Linear Regression'
dfmodel.loc[idx,'RMSE'] = err
idx+=1

# %%
print(err)
# Out:
# 71.0400497532012

# %%
from sklearn.svm import SVR
svr_rbf = SVR(kernel="rbf", C=100, gamma=0.1, epsilon=0.1)
svr_rbf.fit(X_train,y_train)
y_pred=svr_rbf.predict(X_test)
err=np.sqrt((np.square(np.array(y_test)-np.array(y_pred))).sum())
print(err)
dfmodel.loc[idx,'Name'] = 'Support Vector Regression'
dfmodel.loc[idx,'RMSE'] = err
idx+=1
# Out:
# 52.566474506445516

# %%
from sklearn.neighbors import KNeighborsRegressor
KNR=KNeighborsRegressor(5)
KNR.fit(X_train,y_train)
y_pred=KNR.predict(X_test)
err=np.sqrt((np.square(np.array(y_test)-np.array(y_pred))).sum())
print(err)
dfmodel.loc[idx,'Name'] = 'KNeighbors Regression'
dfmodel.loc[idx,'RMSE'] = err
idx+=1
# Out:
# 63.66269664146025

# %%
from sklearn.tree import DecisionTreeRegressor
# dt=DecisionTreeRegressor(class_weight='balanced',min_samples_split=5)
dt=DecisionTreeRegressor()
dt.fit(X_train,y_train)
trainsc=dt.score(X_train,y_train)
y_pred=dt.predict(X_test)
err=np.sqrt((np.square(np.array(y_test)-np.array(y_pred))).sum())
print(err)
dfmodel.loc[idx,'Name'] = 'Decision Tree Regression'
dfmodel.loc[idx,'RMSE'] = err
idx+=1
# Out:
# 77.1298958205522

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()
forest.fit(X_train,y_train)
y_pred=forest.predict(X_test)
err=np.sqrt((np.square(np.array(y_test)-np.array(y_pred))).sum())
print(err)
dfmodel.loc[idx,'Name'] = 'Random Forest Regression'
dfmodel.loc[idx,'RMSE'] = err
idx+=1
# Out:
# 54.56878965542603

# %%
plt.scatter(X_test['IRRADIATION'],y_test)
plt.scatter(X_test['IRRADIATION'],y_pred,c='r')
plt.legend(['Test','Predicted'])
plt.xlabel('IRRADIATION')
plt.ylabel('AC Power')
# Out:
# Text(0, 0.5, 'AC Power')

# %%
plt.scatter(X_test['MODULE_TEMPERATURE'],y_test)
plt.scatter(X_test['MODULE_TEMPERATURE'],y_pred,c='r')
plt.xlabel('MODULE_TEMPERATURE')
plt.legend(['Test','Predicted'])
plt.ylabel('AC Power')
# Out:
# Text(0, 0.5, 'AC Power')

# %%
print(dfmodel)
# Out:
#                         Name       RMSE
# 0          Linear Regression  71.040050
# 1  Support Vector Regression  52.566475
# 2      KNeighbors Regression  63.662697
# 3   Decision Tree Regression  77.129896
# 4   Random Forest Regression  54.568790

# %% [markdown]
# ## Photovoltaic power plant theoretical model

# %% [markdown]
# Variables
# ---
# 1.   Tₘ : Module temperature.
# 2.   Tₐ : Ambient temperature.
# 3.   Gᵢᵣ: Ground level sun irradiance or Irradiation.
# 4. Pₔ: Power output (AC power).

# %% [markdown]
# Constants:-
#
#
# ---
#
#
# 1.   Tₒ : 25ᴼC
# 2.   Gₒ: Standard Irradiation 1000 W/m2
# 3.   α : Module electrical specification.
# 4.   β : Module electrical specification.
# 5.   Vₒ: Open circuit Voltage at Standard Conditions.
# 6.   Iₒ: Short circuit Current at Standard Conditions.
# 7.   STC conditions:  25oC and 1000 W/m2

# %% [markdown]
# #### Physics Model.
# <pre>
# The photovoltaic power output of <b>Pac</b> (taking into account the inverter) can
# be modeled from the product of the open circuit voltage <font size=4><b>V<sub>th</sub></b></font> (Thèvenin
# voltage) and the short circuit current <font size=4><b>I<sub>no</sub></b></font> (Mayer-Norton current):
# </pre>
# $\quad\quad P_{ac}=V_{th}\cdot I_{no}{\color{white}{-------------------------}}(1)$
# <pre>
# And the <font size=4><b>V<sub>th</sub>, I<sub>no</sub></b></font> are defined by<sup><font color="blue">[3]</font></sup>:
#
# </pre>
# $\quad\quad V_{th}=V_{0}[1+\beta(T_m-T_0)] {\color{white}{--------------------\;}}(2)$
#
# $\quad\quad I_{no}=I_{0}[1+\alpha(T_m-T_0)]\Big( \frac{G_{ir}}{G_0} \Big) {\color{white}{------------------}}(3)$
# <pre>
# The module temperature is directly proportional to the Irradiation and to
# the ambient temperature and can be represented by the following empirical
# formula<sup><font color="blue">[4]</font></sup>
# </pre>
# $\quad\quad T_{m}=30-0.0175(G_{ir}-300)+1.14(T_{a}-25) {\color{white}{-----------}}(4)$
# <pre>
# replacing equations <b>(2), (3)</b> and <b>(4)</b> into equation <b>(1)</b> we then get a third
# degree polynomial that can be expressed as follows:
# </pre>
# $\quad\quad P_{ac}= {K_1}{\color{orange}{G_{ir}^3}}+ {K_2}{\color{orange}{G_{ir}^2}}+ {K_3}{\color{orange}{G_{ir}^2T_a}}+ {K_4}{\color{orange}{G_{ir}T_a^2}}+ {K_5}{\color{orange}{G_{ir}T_a}}+ {K_6}{\color{orange}{G_{ir}}}{\color{white}{---}}(5)$
#
# <pre>
# Where <font size=4><b>K<sub>1</sub>, K<sub>2</sub>, ... , K<sub>6</sub></b></font> are constants.
# </pre>
# <pre>
# With the equation <b>(5)</b> we now know which new features we have to create in
# order to build a regressor that predicts <b>AC Power</b>. They are highlighted in
# <font color='orange'>orange</font>.
# Note that this equation have an intercept = 0 in the <font size=4><b>P<sub>ac</sub></b></font> axis
# </pre>

# %% [markdown]
# #### References.
# <pre>
# <sup><font color="blue">[3]</font></sup><font size='2'><b>"A novel Power Output Model for Photovoltaic Systems."</b>
#     <b>Authors</b>: Chiou-Jye Huang, Mao Ting Huang, Chung-Cheng Chen, .
#     <b>Date : </b>2013
#     <b>Refs :</b> Taiwan, DOI: 10.12720/sgce.2.2.139-147
# </font>
# <sup><font color="blue">[4]</font></sup><font size='2'><b> "Photovoltaic Engineering Handbook."</b>
#     <b>Authors</b>: France Lasnier, Tony Gan Ang.
#     <b>Date : </b>1990
#     <b>Refs :</b> USA, ISBN: 9780203743393
# </font>
#
# </pre>

# %%
dfphy=pd.DataFrame()
idx=0

# %%
dfgph=dfg2.copy()
dfgph['G_ir^3']=np.power(dfgph['IRRADIATION'],3)
dfgph['G_ir^2']=np.power(dfgph['IRRADIATION'],2)
dfgph['Ta^2']  = np.power(dfgph['AMBIENT_TEMPERATURE'],2)
dfgph['Gir^2.Ta'] = np.multiply(dfgph['G_ir^2'],dfgph['AMBIENT_TEMPERATURE'])
dfgph['Gir.Ta^2'] = np.multiply(dfgph['IRRADIATION'],dfgph['Ta^2'])
dfgph['Gir.Ta'] =  np.multiply(dfgph['IRRADIATION'],dfgph['AMBIENT_TEMPERATURE'])

# %%
y= dfgph['AC_POWER']
X=dfgph[['IRRADIATION','AMBIENT_TEMPERATURE','MODULE_TEMPERATURE','G_ir^3','G_ir^2','Ta^2','Gir^2.Ta','Gir.Ta^2','Gir.Ta']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=5)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1413, 9) (1413,)
# (942, 9) (942,)

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
pred_y_train = lm.predict(X_train)
y_pred = lm.predict(X_test)

# %%
err=np.sqrt((np.square(np.array(y_test)-np.array(y_pred))).sum())
print(err)
dfphy.loc[idx,'Name'] = 'Linear Regression with PV Model'
dfphy.loc[idx,'RMSE'] = err
idx+=1
# Out:
# 50.625900782791135

# %%
svr_rbf = SVR(kernel="rbf", C=200, gamma=0.1, epsilon=0.1)
svr_rbf.fit(X_train,y_train)
y_pred=svr_rbf.predict(X_test)
err=np.sqrt((np.square(np.array(y_test)-np.array(y_pred))).sum())
print(err)
dfphy.loc[idx,'Name'] = 'Support Vector Regression with PV Model'
dfphy.loc[idx,'RMSE'] = err
idx+=1
# Out:
# 135.81416239688008

# %%
KNR=KNeighborsRegressor(3)
KNR.fit(X_train,y_train)
y_pred=KNR.predict(X_test)
err=np.sqrt((np.square(np.array(y_test)-np.array(y_pred))).sum())
print(err)
dfphy.loc[idx,'Name'] = 'KNeighbors Regression with PV Model'
dfphy.loc[idx,'RMSE'] = err
idx+=1
# Out:
# 58.79094556561804

# %%
dt=DecisionTreeRegressor()
dt.fit(X_train,y_train)
trainsc=dt.score(X_train,y_train)
y_pred=dt.predict(X_test)
err=np.sqrt((np.square(np.array(y_test)-np.array(y_pred))).sum())
print(err)
dfphy.loc[idx,'Name'] = 'Decision Tree Regression with PV Model'
dfphy.loc[idx,'RMSE'] = err
idx+=1
# Out:
# 78.42864206747912

# %%
forest=RandomForestRegressor()
forest.fit(X_train,y_train)
trainsc=forest.score(X_train,y_train)
y_pred=forest.predict(X_test)
err=np.sqrt((np.square(np.array(y_test)-np.array(y_pred))).sum())
print(err)
dfphy.loc[idx,'Name'] = 'Random Forest Regression with PV Model'
dfphy.loc[idx,'RMSE'] = err
idx+=1
# Out:
# 53.17041033836933

# %%
print(dfphy.head())
# Out:
#                                       Name        RMSE
# 0          Linear Regression with PV Model   50.625901
# 1  Support Vector Regression with PV Model  135.814162
# 2      KNeighbors Regression with PV Model   58.790946
# 3   Decision Tree Regression with PV Model   78.428642
# 4   Random Forest Regression with PV Model   53.170410

# %%
plt.scatter(X_test['IRRADIATION'],y_test)
plt.scatter(X_test['IRRADIATION'],y_pred,c='r')
plt.legend(['Test','Predicted'])
plt.xlabel('IRRADIATION')
plt.ylabel('AC Power')
# Out:
# Text(0, 0.5, 'AC Power')

# %%
plt.scatter(X_test['MODULE_TEMPERATURE'],y_test)
plt.scatter(X_test['MODULE_TEMPERATURE'],y_pred,c='r')
plt.xlabel('MODULE_TEMPERATURE')
plt.legend(['Test','Predicted'])
plt.ylabel('AC Power')
# Out:
# Text(0, 0.5, 'AC Power')
